# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint
from bson import Decimal128

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": {'$gt': 20}}

# Capture the results to a variable
results = establishments.find(query)

# Pretty print the first two results
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Skyline Hotel',
#  'AddressLine2': 'Chelmsford Road',
#  'AddressLine3': 'Barnston',
#  'AddressLine4': 'Dunmow',
#  'BusinessName': 'Inferno',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.02974294374,
#  'FHRSID': 1349147,
#  'LocalAuthorityBusinessID': '21/00036/COM',
#  'LocalAuthorityCode': '122',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@uttlesford.gov.uk',
#  'LocalAuthorityName': 'Uttlesford',
#  'LocalAuthorityWebSite': 'http://www.uttlesford.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CM6 1LP',
#  'RatingDate': '2022-01-27T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d0406'),
#  'geocode': {'latitude': Decimal128('51.85643'),
#              'longitude': Decimal128('0.383023')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1349147',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 25, 'Structural': 20}}
# {'AddressLine1': '107 Romford Road',
#  'AddressLine2': 'Stratford',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Stratford News And Wines',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4652.047527485059,
#  'FHRSID': 785554,
#  'LocalAuthorityBusinessID': '08/00054/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E15 4LY',
#  'RatingDate': '2022-04-21T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d0e41'),
#  'geocode': {'latitude': Decimal128('51.542772'),
#              'longitude': Decimal128('0.008382')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/785554',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 15}}
# {'AddressLine1': '',
#  'AddressLine2': '419 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'The Plough & Harrow',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4652.681024571728,
#  'FHRSID': 514156,
#  'LocalAuthorityBusinessID': '147',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4JU',
#  'RatingDate': '2022-03-29T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d0ff5'),
#  'geocode': {'latitude': Decimal128('51.558138'),
#              'longitude': Decimal128('0.006434')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514156',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 25}}
# {'AddressLine1': '',
#  'AddressLine2': '497 High Road',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'Chicks',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4652.699935107432,
#  'FHRSID': 514651,
#  'LocalAuthorityBusinessID': '47178',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4PG',
#  'RatingDate': '2021-09-07T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d1004'),
#  'geocode': {'latitude': Decimal128('51.5593505'),
#              'longitude': Decimal128('0.0071334')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514651',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 25}}
# {'AddressLine1': '',
#  'AddressLine2': '647-661 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'The Continental Food Exchange/TFC Leytonstone',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4652.776654347289,
#  'FHRSID': 514221,
#  'LocalAuthorityBusinessID': '17220',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 4RD',
#  'RatingDate': '2021-10-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d103b'),
#  'geocode': {'latitude': Decimal128('51.563902'),
#              'longitude': Decimal128('0.009602')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/514221',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 25}}
# {'AddressLine1': '',
#  'AddressLine2': '885 High Road Leytonstone',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'O42',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4652.86583773827,
#  'FHRSID': 552296,
#  'LocalAuthorityBusinessID': '63877',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E11 1HR',
#  'RatingDate': '2022-05-20T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d1084'),
#  'geocode': {'latitude': Decimal128('51.570848'),
#              'longitude': Decimal128('0.014137')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/552296',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 25}}
# {'AddressLine1': 'Whipps Cross University Hospital',
#  'AddressLine2': 'Whipps Cross Road',
#  'AddressLine3': '',
#  'AddressLine4': 'Leytonstone',
#  'BusinessName': 'Busy Bees at Leytonstone',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4653.495442188015,
#  'FHRSID': 1351355,
#  'LocalAuthorityBusinessID': '348976',
#  'LocalAuthorityCode': '531',
#  'LocalAuthorityEmailAddress': 'environmentalhealth@walthamforest.gov.uk',
#  'LocalAuthorityName': 'Waltham Forest',
#  'LocalAuthorityWebSite': 'http://www.walthamforest.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'E11 1NR',
#  'RatingDate': '2022-01-12T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('672bd82122116181ae6d1200'),
#  'geocode': {'latitude': Decimal128('51.5774342'),
#              'longitude': Decimal128('0.0034702')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1351355',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 30, 'Hygiene': 25, 'Structural': 25}}

# %%
# Convert the result to a Pandas DataFrame
new_df = pd.DataFrame(establishments.find(query))
# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(new_df)}")
# Display the first 10 rows of the DataFrame
new_df.head(10)
# Out:
# Number of rows in the DataFrame: 7
#                         _id   FHRSID  ChangesByServerID  \
# 0  672bd82122116181ae6d0406  1349147                  0
# 1  672bd82122116181ae6d0e41   785554                  0
# 2  672bd82122116181ae6d0ff5   514156                  0
# 3  672bd82122116181ae6d1004   514651                  0
# 4  672bd82122116181ae6d103b   514221                  0
# 5  672bd82122116181ae6d1084   552296                  0
# 6  672bd82122116181ae6d1200  1351355                  0
#
#   LocalAuthorityBusinessID                                   BusinessName  \
# 0             21/00036/COM                                        Inferno
# 1            08/00054/FOOD                       Stratford News And Wines
# 2                      147                            The Plough & Harrow
# 3                    47178                                         Chicks
# 4                    17220  The Continental Food Exchange/TFC Leytonstone
# 5                    63877                                            O42
# 6                   348976                       Busy Bees at Leytonstone
#
#               BusinessType  BusinessTypeID                      AddressLine1  \
# 0   Takeaway/sandwich shop            7844                     Skyline Hotel
# 1        Retailers - other            4613                  107 Romford Road
# 2        Pub/bar/nightclub            7843
# 3   Takeaway/sandwich shop            7844
# 4        Retailers - other            4613
# 5  Restaurant/Cafe/Canteen               1
# 6          Caring Premises               5  Whipps Cross University Hospital
#
#                     AddressLine2 AddressLine3  ...  \
# 0                Chelmsford Road     Barnston  ...
# 1                      Stratford       London  ...
# 2      419 High Road Leytonstone               ...
# 3                  497 High Road               ...
# 4  647-661 High Road Leytonstone               ...
# 5      885 High Road Leytonstone               ...
# 6              Whipps Cross Road               ...
#
#              LocalAuthorityWebSite                LocalAuthorityEmailAddress  \
# 0     http://www.uttlesford.gov.uk     environmentalhealth@uttlesford.gov.uk
# 1        https://www.newham.gov.uk                        food@newham.gov.uk
# 2  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 3  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 4  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 5  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
# 6  http://www.walthamforest.gov.uk  environmentalhealth@walthamforest.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 25, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 25, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 25, 'Structural': 25, 'ConfidenceI...        FHRS
#
#                                             geocode RightToReply     Distance  \
# 0     {'longitude': 0.383023, 'latitude': 51.85643}               4650.029743
# 1    {'longitude': 0.008382, 'latitude': 51.542772}               4652.047527
# 2    {'longitude': 0.006434, 'latitude': 51.558138}               4652.681025
# 3  {'longitude': 0.0071334, 'latitude': 51.5593505}               4652.699935
# 4    {'longitude': 0.009602, 'latitude': 51.563902}               4652.776654
# 5    {'longitude': 0.014137, 'latitude': 51.570848}               4652.865838
# 6  {'longitude': 0.0034702, 'latitude': 51.5774342}               4653.495442
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6             True  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [7 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
ext_query = {"LocalAuthorityName": {"$regex": "London", "$options": "i"}, "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(ext_query)
print(count)
# Display the first document in the results using pprint
establishments.find_one(ext_query)
# Out:
# 33
# {'_id': ObjectId('672bd82022116181ae6cb7a2'),
#  'FHRSID': 621707,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'PostCode': 'ME12',
#  'Phone': '',
#  'RatingValue': 4,
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2021-10-18T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': Decimal128('0.508551'),
#   'latitude': Decimal128('51.369321')},
#  'RightToReply': '',
#  'Distance': 4627.439467780196,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/621707'}]}

# %%
# Convert the result to a Pandas DataFrame
convert_results = establishments.find(ext_query)

# Convert the MongoDB query result to a Pandas DataFrame
convert_df = pd.DataFrame(convert_results)

# Display the number of rows in the DataFrame
print(f"Number of rows in the DataFrame: {len(convert_df)}")

# Display the first 10 rows of the DataFrame
convert_df.head(10)
# Out:
# Number of rows in the DataFrame: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  672bd82022116181ae6cb7a2   621707                  0
# 1  672bd82122116181ae6cbac8  1130836                  0
# 2  672bd82122116181ae6cc617   293783                  0
# 3  672bd82122116181ae6cd417  1315095                  0
# 4  672bd82122116181ae6cd418   294474                  0
# 5  672bd82122116181ae6cdb1f   294900                  0
# 6  672bd82122116181ae6cfc2d   293756                  0
# 7  672bd82122116181ae6cfff5   878523                  0
# 8  672bd82122116181ae6d0008   293772                  0
# 9  672bd82122116181ae6d000b   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %%
#Define the location of the "Penang Flavours" restaurant
location_query = {"BusinessName": "Penang Flavours"}

# Retrieve latitude and longitude of "Penang Flavours"
penang_flavours = establishments.find_one(location_query, {"geocode.latitude": 1, "geocode.longitude": 1})
penang_flavours
# Out:
# {'_id': ObjectId('672bd8371db41b40672cec30'),
#  'geocode': {'longitude': Decimal128('0.08384000'),
#   'latitude': Decimal128('51.49014200')}}

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#Define the location of the "Penang Flavours" restaurant
location_query = {"BusinessName": "Penang Flavours"}

# Retrieve latitude and longitude of "Penang Flavours"
penang_flavours = establishments.find_one(location_query, {"geocode.latitude": 1, "geocode.longitude": 1})

latitude = float(penang_flavours["geocode"]["latitude"].to_decimal()) if isinstance(penang_flavours["geocode"]["latitude"], Decimal128) else penang_flavours["geocode"]["latitude"]
longitude = float(penang_flavours["geocode"]["longitude"].to_decimal()) if isinstance(penang_flavours["geocode"]["longitude"], Decimal128) else penang_flavours["geocode"]["longitude"]

#Define the degree search range
degree_search = 0.01

#Build the query for establishments with RatingValue = 5 and within the search range of latitude/longitude
query = {
        "RatingValue": 5,
        "scores.hygiene": {"$exists": True},
        "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
        "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}

#Sort by hygiene score (ascending) and limit the results to top 5
sort = [("scores.hygiene", 1)]  # Sort by lowest hygiene score
fields = {"BusinessName": 1, "scores.hygiene": 1, "geocode.latitude": 1, "geocode.longitude": 1, "RatingValue": 1}
    
# Fetch the top 5 establishments that match the query
top_5_establishments = list(establishments.find(query, fields).sort(sort).limit(5))

# Print the results
for establishment in top_5_establishments:
    print(establishment)

# %%
query
# Out:
# {'RatingValue': 5,
#  'scores.hygiene': {'$exists': True},
#  'geocode.latitude': {'$gte': 51.480142, '$lte': 51.500142},
#  'geocode.longitude': {'$gte': 0.07384, '$lte': 0.09383999999999999}}

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
